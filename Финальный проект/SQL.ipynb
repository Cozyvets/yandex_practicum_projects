# %% [markdown]
# ## Проект по SQL

# %% [markdown]
# ## Описание

# %% [markdown]
# Коронавирус застал мир врасплох, изменив привычный порядок вещей. В свободное время жители городов больше не выходят на улицу, не посещают кафе и торговые центры. Зато стало больше времени для книг. Это заметили стартаперы — и бросились создавать приложения для тех, кто любит читать.
# Ваша компания решила быть на волне и купила крупный сервис для чтения книг по подписке. Ваша первая задача как аналитика — проанализировать базу данных.
# В ней — информация о книгах, издательствах, авторах, а также пользовательские обзоры книг. Эти данные помогут сформулировать ценностное предложение для нового продукта.

# %% [markdown]
# ## Задачи

# %% [markdown]
# - Посчитайте, сколько книг вышло после 1 января 2000 года;
#
# - Для каждой книги посчитайте количество обзоров и среднюю оценку;
#
# - Определите издательство, которое выпустило наибольшее число книг толще 50 страниц — так вы исключите из анализа брошюры;
#
# - Определите автора с самой высокой средней оценкой книг — учитывайте только книги с 50 и более оценками;
#
# - Посчитайте среднее количество обзоров от пользователей, которые поставили больше 48 оценок.

# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Подключение к данным

# %%
db_config = {'user': 'praktikum_student', 
 'pwd': 'Sdf4$2;d-d30pp', 
 'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
 'port': 6432, 
 'db': 'data-analyst-final-project-db'} 
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
 db_config['pwd'],
 db_config['host'],
 db_config['port'],
 db_config['db'])

engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %% [markdown]
# ## Изучение данных

# %%
tables = ['books', 'authors', 'publishers', 'ratings', 'reviews']

for table in tables:
    query = f"SELECT * FROM {table}"
    data = pd.io.sql.read_sql(query, con=engine)
    
    print("\n")
    print(f"{table}")
    
    display(data)
    
    print(data.info())
    
    print("\nПроопуски:")
    print(data.isnull().sum())
    
    print("\nДубликаты:")
    print(data.duplicated().sum())
# Out:
# books
#      book_id  author_id                                              title  \
# 0          1        546                                       'Salem's Lot
# 1          2        465                 1 000 Places to See Before You Die
# 2          3        407  13 Little Blue Envelopes (Little Blue Envelope...
# 3          4         82  1491: New Revelations of the Americas Before C...
# 4          5        125                                               1776
# ..       ...        ...                                                ...
# 995      996        571           Wyrd Sisters (Discworld  #6; Witches #2)
# 996      997        454                        Xenocide (Ender's Saga  #3)
# 997      998        201                                    Year of Wonders
# 998      999         94                        You Suck (A Love Story  #2)
# 999     1000        509  Zen and the Art of Motorcycle Maintenance: An ...
#
#      num_pages publication_date  publisher_id
# ...

# %% [markdown]
# Пропуски и дубликаты не обнаружены

# %% [markdown]
# ## Количество книг, вышедших после 1 января 2000 года

# %%
query = '''
        SELECT COUNT(*) AS book_count
        FROM books
        WHERE publication_date > '2000-01-01'
        '''
result = pd.io.sql.read_sql(query, con = engine)

book_count = result['book_count'].values[0]
print("Количество книг, вышедших после 1 января 2000 года:", book_count)
# Out:
# Количество книг, вышедших после 1 января 2000 года: 819

# %% [markdown]
# ## Количество обзоров и средних оценок на книги

# %%
query = '''
SELECT books.book_id, 
       books.title, 
       COUNT(DISTINCT review_id) AS cnt_reviews, 
       ROUND(AVG(rating), 2) AS avg_rating
       
FROM books
LEFT JOIN reviews ON books.book_id = reviews.book_id
LEFT JOIN ratings ON books.book_id = ratings.book_id

GROUP BY books.book_id, books.title
ORDER BY cnt_reviews DESC

'''
pd.io.sql.read_sql(query, con = engine)
# Out:
#      book_id                                              title  cnt_reviews  \
# 0        948                            Twilight (Twilight  #1)            7
# 1        963                                Water for Elephants            6
# 2        734                                   The Glass Castle            6
# 3        302  Harry Potter and the Prisoner of Azkaban (Harr...            6
# 4        695  The Curious Incident of the Dog in the Night-Time            6
# ..       ...                                                ...          ...
# 995       83    Anne Rice's The Vampire Lestat: A Graphic Novel            0
# 996      808                            The Natural Way to Draw            0
# 997      672   The Cat in the Hat and Other Dr. Seuss Favorites            0
# 998      221                          Essential Tales and Poems            0
# 999      191  Disney's Beauty and the Beast (A Little Golden...            0
#
#      avg_rating
# 0          3.66
# ...

# %% [markdown]
# Топ-3 нкиги по количеству обзоров:
#
# - Twilight (Twilight #1) (7 rev) (3.66)
#
# - Water for Elephants (6 rev) (3.98)
#
# - The Glass Castle (6 rev) (4.21)
#
# Топ-3 нкиги по рейтингу:
#
# - Arrows of the Queen (Heralds of Valdemar #1) (2 rev)(5.00)
#
# - The Walking Dead Book One (The Walking Dead #1-12) (2 rev) (5.00)
#
# - Light in August (2 rev) (5.00)

# %% [markdown]
# ## Издательство, которое выпустило наибольшее число книг толще 50 страниц

# %%
query = '''
        SELECT p.publisher, COUNT(b.book_id) AS book_count
        FROM publishers p
        INNER JOIN books b ON p.publisher_id = b.publisher_id
        WHERE b.num_pages > 50
        GROUP BY p.publisher
        ORDER BY book_count DESC
        LIMIT 1
        '''
publisher_result = pd.read_sql_query(query, con=engine)

publisher = publisher_result['publisher'].values[0]
book_count = publisher_result['book_count'].values[0]
print("Издательство:", publisher)
print("Количество книг:", book_count)
# Out:
# Издательство: Penguin Books
# Количество книг: 42

# %% [markdown]
# ## Автор с самой высокой средней оценкой книг

# %%
query = '''
        SELECT a.author, AVG(r.rating) AS average_rating
        FROM authors a
        INNER JOIN (
            SELECT b.author_id, b.book_id
            FROM books b
            INNER JOIN ratings r ON b.book_id = r.book_id
            GROUP BY b.author_id, b.book_id
            HAVING COUNT(r.rating_id) >= 50
        ) AS filtered_books ON a.author_id = filtered_books.author_id
        INNER JOIN ratings r ON filtered_books.book_id = r.book_id
        GROUP BY a.author
        ORDER BY average_rating DESC
        LIMIT 1
        '''

author_result = pd.read_sql_query(query, con=engine)

author = author_result['author'].values[0]
average_rating = author_result['average_rating'].values[0]
print("Автор:", author)
print("Средняя оценка:", round(average_rating, 2))
# Out:
# Автор: J.K. Rowling/Mary GrandPré
# Средняя оценка: 4.29

# %% [markdown]
# ## Среднее количество обзоров от пользователей, которые поставили больше 48 оценок

# %%
query = '''
        SELECT AVG(count_reviews)
        FROM (
            SELECT username, COUNT(*) AS count_reviews
            FROM reviews
            WHERE username IN (
                SELECT username
                FROM ratings
                GROUP BY username
                HAVING COUNT(*) > 50)
            GROUP BY username
        ) AS review_counts
        '''
average_review_count_result = pd.read_sql_query(query, con=engine)

average_review_count = average_review_count_result['avg'].values[0]
print("Среднее количество обзоров от пользователей, которые поставили больше 48 оценок:", round(average_review_count), 2)
# Out:
# Среднее количество обзоров от пользователей, которые поставили больше 48 оценок: 24 2

# %% [markdown]
# ## Вывод

# %% [markdown]
# В ходе выполнения исследовательской работы были изучены данные и даны ответы на поставленные вопросы
#
# - После 1 января 2000 года вышло 819 книг
#
# - Количество обзоров и средних оценок на книги
#
#      Топ-3 нкиги по количеству обзоров:
#
#      - Twilight (Twilight #1) (7 rev) (3.66 rat)
#
#      - Water for Elephants (6 rev) (3.98 rat)
#
#      - The Glass Castle (6 rev) (4.21 rat)
#
#     Топ-3 нкиги по рейтингу:
#
#      - Arrows of the Queen (Heralds of Valdemar #1) (2 rev) (5.00 rat)
#
#      - The Walking Dead Book One (The Walking Dead #1-12) (2 rev) (5.00 rat)
#
#      - Light in August (2 rev) (5.00 rat)
#
# - Penguin Books, выпустило наибольшее число книг толще 50 страниц (42)
#
# - J.K. Rowling/Mary GrandPré, автор с самой высокой средней оценкой книг (4.29 rat)
#
# - Среднее количество обзоров от пользователей, которые поставили больше 48 оценок равно 24 rev
